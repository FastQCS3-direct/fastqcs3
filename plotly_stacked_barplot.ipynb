# %%
import data_prep_stack_barplots as prep 
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import random

from qiime2.plugins import feature_table
from qiime2 import Artifact

# %%
# NOTE: THESE DATA IMPORTS WILL NOT WORK IF YOU WANT TO MESS WITH THIS YOU HAVE TO CHANGE THIS TO THE LOCATION OF THE 
# DATA ON YOUR DEVICE
tax = pd.read_csv("data/taxonomy.tsv", sep='\t')
tax[['kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']] = tax['Taxon'].str.split(';', expand=True)
tax.shape
tax.set_index('Feature ID', inplace=True)

# %%
# NOTE: THESE DATA IMPORTS WILL NOT WORK IF YOU WANT TO MESS WITH THIS YOU HAVE TO CHANGE THIS TO THE LOCATION OF THE 
# DATA ON YOUR DEVICE
unrarefied_table = Artifact.load('tutorial/table.qza')
rarefy_result = feature_table.methods.rarefy(table=unrarefied_table, sampling_depth=100)
rarefied_table = rarefy_result.rarefied_table

t = rarefied_table.view(pd.DataFrame)
t.head()
# Out:
#         4b5eeb300368260019c1fbc7a3c718fc  fe30ff0f71a38a39cf1717ec2be3a2fc  \
# L1S105                              24.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               0.0
# L1S281                               0.0                               0.0
#
#         d29fe3c70564fc0f69f2c03e0d1e5561  868528ca947bc57b69ffdf83e6b73bae  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                              22.0
# L1S208                               0.0                              26.0
# L1S257                               0.0                              18.0
# L1S281                               0.0                              20.0
#
#         154709e160e8cada6bfb21115acc80f5  1d2e5f3444ca750c85302ceee2473331  \
# L1S105                              15.0                               0.0
# L1S140                              21.0                               0.0
# L1S208                              11.0                               0.0
# L1S257                               4.0                               0.0
# L1S281                               2.0                               0.0
#
#         0305a4993ecf2d8ef4149fdfc7592603  cb2fe0146e2fbcb101050edb996a0ee2  \
# L1S105                              12.0                               0.0
# L1S140                              12.0                               0.0
# L1S208                              12.0                               0.0
# L1S257                              12.0                               0.0
# L1S281                               8.0                               0.0
#
#         997056ba80681bbbdd5d09aa591eadc0  3c9c437f27aca05f8db167cd080ff1ec  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               0.0
# L1S281                               0.0                               0.0
#
#         ...  d4c5acaf755ef50d18008aa6c79f60b0  \
# L1S105  ...                               0.0
# L1S140  ...                               0.0
# L1S208  ...                               0.0
# L1S257  ...                               0.0
# L1S281  ...                               0.0
#
#         a0daabc3e11deb9b43aafbf3c8e31e35  1076b2b7de5233cc917c9425aa2ea200  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               1.0
# L1S281                               0.0                               0.0
#
#         464ff59b632870b5028ed3092b9443ff  77f79d776f3845bc2901cf9c4229de0b  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               0.0
# L1S281                               0.0                               0.0
#
#         3b0e180ea70b1a946a6214eacb539c97  5af6e343611d715985e35e7a3e5671cb  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               0.0
# L1S281                               0.0                               0.0
#
#         317c0beca40f29f3aff863b8f028fd48  9cd758ad7582755a7f52f2b003787795  \
# L1S105                               0.0                               0.0
# L1S140                               0.0                               0.0
# L1S208                               0.0                               0.0
# L1S257                               0.0                               0.0
# L1S281                               0.0                               0.0
#
#         c80037fe31359840bb73250f330b60e3
# L1S105                               0.0
# L1S140                               0.0
# L1S208                               0.0
# L1S257                               0.0
# L1S281                               0.0
#
# [5 rows x 356 columns]

# %%
kingdom_df, phylum_df, class_df, order_df, family_df, genus_df, species_df = prep.prepare_data_stacked_barplots(t, tax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'd46bfd723f625e317606ae28580eba3e'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-214687e3dcb4> in <module>
# ----> 1 kingdom_df, phylum_df, class_df, order_df, family_df, genus_df, species_df = prep.prepare_data_stacked_barplots(t, tax)
#
# /mnt/c/Users/cjmar/ChemE545and546/Project/fastqcs3/data_prep_stack_barplots.py in prepare_data_stacked_barplots(feature_table, taxonomy_table)
#      53     kingdom_df_0, phylum_df_0, class_df_0, order_df_0, family_df_0, genus_df_0, species_df_0 = make_tax_dfs(taxon_list, feature_table)
#      54     kingdom_df, phylum_df, class_df, order_df, family_df, genus_df, species_df = fill_tax_dfs(kingdom_df_0, phylum_df_0, class_df_0, order_df_0,
# ---> 55                                                                                               family_df_0, genus_df_0, species_df_0, feature_table, taxonomy_red)
#      56     return kingdom_df, phylum_df, class_df, order_df, family_df, genus_df, species_df
#
# /mnt/c/Users/cjmar/ChemE545and546/Project/fastqcs3/data_prep_stack_barplots.py in fill_tax_dfs(kingdom_df, phylum_df, class_df, order_df, family_df, genus_df, species_df, feature_table, taxonomy_red)
#      37         for featid in row.index:
#      38             # iterate over each feature id (sequence) in a sample and add appropriate prevalence to each taxonomy df
# ---> 39             tax_list = taxonomy_red.loc[featid] # gets a list of the corresponding kingdom, phylum, etc for the feature id
#      40             kingdom_df[tax_list[0]][sample] += feature_table.loc[sample][featid] / 100
#      41             phylum_df.loc[sample][tax_list[1]] += feature_table.loc[sample][featid] / 100
#
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/qiime2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'd46bfd723f625e317606ae28580eba3e'

# %%
phylum_df.head()

# %%
fig = go.Figure()

for item, col in kingdom_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Kingdom Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in phylum_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Phylum Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in class_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Class Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in order_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Order Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in family_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Family Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in genus_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Genus Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()

# %%
fig = go.Figure()

for item, col in species_df.iteritems():
    fig.add_trace(go.Bar(name=item, x=col.index, y=col))

fig.update_layout(barmode='stack')
fig.update_layout(title_text='Species Stacked Barplots', title_x=0.33)
fig.update_xaxes(title_text='Sample')
fig.update_yaxes(title_text='Relative Frequency')
fig.show()
